# %%
gRNA_TARGET_LENGTH = 20
PAM_LENGTH = 3
FORWARD = 0
REVERSE = 1

f = open("ADE2 sequence.txt","r")

Dna = f.readline()
Dna = Dna[:len(Dna) - 1]

def MakeGRNAdict(Dna):
    PAMsites = FindPAMSites(Dna)
    
    gRNAdict = []
    
    for location in PAMsites[FORWARD]:
        start = location - gRNA_TARGET_LENGTH
        sequence = Dna[start:start + gRNA_TARGET_LENGTH]
        gRNAdict.append({"location": start + 1,
                            "type": "Forward",
                            "sequence": sequence,
                            "PAM": Dna[location:location + PAM_LENGTH],
                            "20-mers matching": PatternCount(Dna, sequence),
                            "12-mers matching": PatternCount12mer(Dna, sequence, FORWARD),
                            "8-mers matching": PatternCount8mer(Dna, sequence, FORWARD)
                           })
        
    for location in PAMsites[REVERSE]:
        start = location + 1
        sequence = Dna[start:start + gRNA_TARGET_LENGTH]
        gRNAdict.append({"location": start + 1,
                            "type": "Reverse",
                            "sequence": sequence,
                            "PAM": Dna[start - PAM_LENGTH:start],
                            "20-mers matching": PatternCount(Dna, sequence),
                            "12-mers matching": PatternCount12mer(Dna, sequence, REVERSE),
                            "8-mers matching": PatternCount8mer(Dna, sequence, REVERSE)
                           })
        
    return gRNAdict        

def FindPAMSites(Dna):
    ForwardPAMlocations = []
    ReversePAMlocations = []
    
    for i in range(len(Dna) - 2):
        potentialPAM = Dna[i:i + 2]
        
        if potentialPAM == "GG" and i >= gRNA_TARGET_LENGTH + PAM_LENGTH:
            ForwardPAMlocations.append(i - 1)
        elif potentialPAM == "CC" and i < len(Dna) - gRNA_TARGET_LENGTH - PAM_LENGTH:
            ReversePAMlocations.append(i + 2)
            
    return [ForwardPAMlocations, ReversePAMlocations]
    
def PatternCount(text, pattern):
    count = 0
    for i in range(0, len(text) - len(pattern) + 1):
        if text[i:i + len(pattern)] == pattern and (text[i + len(pattern) + 1:i + len(pattern) + PAM_LENGTH] == "GG" or text[i - PAM_LENGTH:i - PAM_LENGTH + 2] == "CC"):
            count += 1
    return count

def PatternCount12mer(text, pattern, direction):
    count = 0
    pattern = pattern[len(pattern) - 12:len(pattern)] if direction == FORWARD else pattern[0:12]
    for i in range(0, len(text) - len(pattern) + 1):
        if text[i:i + len(pattern)] == pattern and ((text[i + len(pattern) + 1:i + len(pattern) + PAM_LENGTH] == "GG" and direction == FORWARD) or (text[i - PAM_LENGTH:i - PAM_LENGTH + 2] == "CC" and direction == REVERSE)):
            count += 1
    return count

def PatternCount8mer(text, pattern, direction):
    count = 0
    pattern = pattern[len(pattern) - 8:len(pattern)] if direction == FORWARD else pattern[0:8]
    for i in range(0, len(text) - len(pattern) + 1):
        if text[i:i + len(pattern)] == pattern and ((text[i + len(pattern) + 1:i + len(pattern) + PAM_LENGTH] == "GG" and direction == FORWARD) or (text[i - PAM_LENGTH:i - PAM_LENGTH + 2] == "CC" and direction == REVERSE)):
            count += 1
    return count

for gRNA in MakeGRNAdict(Dna):
    print(gRNA)

f.close()
# Out:
# {'location': 35, 'type': 'Forward', 'sequence': 'CTATTACGAAATTACTCTAT', 'PAM': 'AGG', '20-mers matching': 1, '12-mers matching': 1, '8-mers matching': 1}
# {'location': 55, 'type': 'Forward', 'sequence': 'AGGTTAGAATGTCATCCCAT', 'PAM': 'AGG', '20-mers matching': 1, '12-mers matching': 1, '8-mers matching': 1}
# {'location':
 'PAM': 'TGG', '20-mers matching': 1, '12-mers matching': 1, '8-mers matching': 1}
# {'location': 3199, 'type': 'Forward', 'sequence': 'CCCTATAATGTTCCCTTGGA', 'PAM': 'AGG', '20-mers matching': 1, '12-mers matching': 1, '8-mers matching': 1}
# {'location': 3266, 'type': 'Forward', 'sequence': 'GTCCGAATTCTTTGCTTCTA', 'PAM': 'AGG', '20-mers matching': 1, '12-mers matching': 1, '8-mers matching': 1}
# {'location': 3288, 'type': 'Forward', 'sequence': 'GACAACTTTCCTCCAACAAA', 'PAM': 'TGG', '20-mers matching': 1, '12-mers matching': 1, '8-mers matching': 1}
# {'location': 3333, 'type': 'Forward', 'sequence': 'GATTTAACTAACCTCATCAA', 'PAM': 'CGG', '20-mers matching': 1, '12-mers matching': 1, '8-mers matching': 1}
# {'location': 3350, 'type': 'Forward', 'sequence': 'CAACGGCTCGTATATTTGAA', 'PAM': 'AGG', '20-mers matching': 1, '12-mers matching': 1, '8-mers matching': 1}
# {'location': 3360, 'type': 'Forward', 'sequence': 'TATATTTGAAAGGTAAAGAT', 'PAM': 'AGG', '20-mers matching': 1, '12-mers matching': 1, '8-mers matching': 1}
# {'location': 3361, 'type': 'Forward', 'sequence': 'ATATTTGAAAGGTAAAGATA', 'PAM': 'GGG', '20-mers matching': 1, '12-mers matching': 1, '8-mers matching': 1}
# {'location': 3365, 'type': 'Forward', 'sequence': 'TTGAAAGGTAAAGATAGGGT', 'PAM': 'TGG', '20-mers matching': 1, '12-mers matching': 1, '8-mers matching': 1}
# {'location': 3366, 'type': 'Forward', 'sequence': 'TGAAAGGTAAAGATAGGGTT', 'PAM': 'GGG', '20-mers matching': 1, '12-mers matching': 1, '8-mers matching': 1}
# {'location': 3367, 'type': 'Forward', 'sequence': 'GAAAGGTAAAGATAGGGTTG', 'PAM': 'GGG', '20-mers matching': 1, '12-mers matching': 1, '8-mers matching': 1}
# {'location': 3435, 'type': 'Forward', 'sequence': 'TCTTGTTCCGTTAAAATATT', 'PAM': 'TGG', '20-mers matching': 1, '12-mers matching': 1, '8-mers matching': 1}
# {'location': 3443, 'type': 'Forward', 'sequence': 'CGTTAAAATATTTGGCGTTT', 'PAM': 'CGG', '20-mers matching': 1, '12-mers matching': 1, '8-mers matching': 1}
# {'location': 3502, 'type': 'Forward', 'sequence': 'CTATTTCTTCTATGACTAGC', 'PAM': 'TGG', '20-mers matching': 1, '12-mers matching': 1, '8-mers matching': 1}
# {'location': 3503, 'type': 'Forward', 'sequence': 'TATTTCTTCTATGACTAGCT', 'PAM': 'GGG', '20-mers matching': 1, '12-mers matching': 1, '8-mers matching': 1}
# {'location': 3588, 'type': 'Forward', 'sequence': 'ATGCAGACAGATAGTATCAT', 'PAM': 'CGG', '20-mers matching': 1, '12-mers matching': 1, '8-mers matching': 1}
# {'location': 73, 'type': 'Reverse', 'sequence': 'ATAGGTATGGCCCTTTTAAA', 'PAM': 'CCC', '20-mers matching': 1, '12-mers matching': 1, '8-mers matching': 1}
# {'location': 74, 'type': 'Reverse', 'sequence': 'TAGGTATGGCCCTTTTAAAG', 'PAM': 'CCA', '20-mers matching': 1, '12-mers matching': 1, '8-mers matching': 1}
# {'location': 86, 'type': 'Reverse', 'sequence': 'TTTTAAAGAAGTATCTCCAC', 'PAM': 'CCC', '20-mers matching': 1, '12-mers matching': 1, '8-mers matching': 1}
# {'location': 87, 'type': 'Reverse', 'sequence': 'TTTAAAGAAGTATCTCCACA', 'PAM': 'CCT', '20-mers matching': 1, '12-mers matching': 1, '8-mers matching': 1}
# {'location': 105, 'type': 'Reverse', 'sequence': 'CAATCAATTGCGAGAAGCCT', 'PAM': 'CCA', '20-mers matching': 1, '12-mers matching': 1, '8-mers matching': 1}
# {'location': 125, 'type': 'Reverse', 'sequence': 'ATCTAGAATCAAAACGACAC', 'PAM': 'CCT', '20-mers matching': 1, '12-mers matching': 1, '8-mers matching': 1}
# {'location': 155, 'type': 'Reverse', 'sequence': 'AAAAGGGAGATTCGACCAAC', 'PAM': 'CCA', '20-mers matching': 1, '12-mers matching': 1, '8-mers matching': 1}
# {'location': 173, 'type': 'Reverse', 'sequence': 'ACACTTCCTCTACCATTGCA', 'PAM': 'CCA', '20-mers matching': 1, '12-mers matching': 1, '8-mers matching': 1}
# {'location': 182, 'type': 'Reverse', 'sequence': 'CTACCATTGCATCATCATCT', 'PAM': 'CCT', '20-mers matching': 1, '12-mers matching': 1, '8-mers matching': 1}
# {'location': 188, 'type': 'Reverse', 'sequence': 'TTGCATCATCATCTTTCGCT', 'PAM': 'CCA', '20-mers matching': 1, '12-mers matching': 1, '8-mers matching': 1}
# {'location': 223, 'type': 'Reverse', 'sequence': 'CTATCTTCAAACGAATCAGG', 'PAM': 'CCT', '20-mers matching': 1, '12-mers matching': 1, '8-mers matching': 1}
# {'location': 299, 'type': 'Reverse', 'sequence': 'CTCAAAAGGAAGACTAGTAA', 'PAM': 'CCA', '20-mers matching': 1, '12-mers matching': 1, '8-mers matching': 1}
# {'location': 324, 'type': 'Reverse', 'sequence': 'TATCGTGATTAACGTATTAC', 'PAM': 'CCG', '20-mers matching': 1, '12-mers matching': 1, '8-mers matching': 1}
# {'location': 386, 'type': 'Reverse', 'sequence': 'AATGTGTCCATCTGACATTA', 'PAM': 'CCC', '20-mers matching': 1, '12-mers matching': 1, '8-mers matching': 1}
# {'location': 387, 'type': 'Reverse', 'sequence': 'ATGTGTCCATCTGACATTAC', 'PAM': 'CCA', '20-mers matching': 1, '12-mers matching': 1, '8-mers matching': 1}
# {'location': 396, 'type': 'Reverse', 'sequence': 'TCTGACATTACTATTTTGCA', 'PAM': 'CCA', '20-mers matching': 1, '12-mers matching': 1, '8-mers matching': 1}
# {'location': 452, 'type': 'Reverse', 'sequence': 'GTATATCATCTCATTTCCGT', 'PAM': 'CCA', '20-mers matching': 1, '12-mers matching': 1, '8-mers matching': 1}
# {'location': 471, 'type': 'Reverse', 'sequence': 'TAAATACCAAATGTATTATA', 'PAM': 'CCG', '20-mers matching': 1, '12-mers matching': 1, '8-mers matching': 1}
# {'location': 480, 'type': 'Reverse', 'sequence': 'AATGTATTATATATTGAAAG', 'PAM': 'CCA', '20-mers matching': 1, '12-mers matching': 1, '8-mers matching': 1}
# {'location': 510, 'type': 'Reverse', 'sequence': 'GGTTATTATAAAAGAAACTT', 'PAM': 'CCA', '20-mers matching': 1, '12-mers matching': 1, '8-mers matching': 1}
# {'location': 564, 'type': 'Reverse', 'sequence': 'AGTTTCATGAAATTTTAAAG', 'PAM': 'CCT', '20-mers matching': 1, '12-mers matching': 1, '8-mers matching': 1}
# {'location': 605, 'type': 'Reverse', 'sequence': 'TTTGATGCGGAATTGACTTT', 'PAM': 'CCT', '20-mers matching': 1, '12-mers matching': 1, '8-mers matching': 1}
# {'location': 706, 'type': 'Reverse', 'sequence': 'AGAATTTTGTAACACCAACA', 'PAM': 'CCG', '20-mers matching': 1, '12-mers matching': 1, '8-mers matching': 1}
# {'location': 723, 'type': 'Reverse', 'sequence': 'ACATAACACTGACATCTTTA', 'PAM': 'CCA', '20-mers matching': 1, '12-mers matching': 1, '8-mers matching': 1}
# {'location': 832, 'type': 'Reverse', 'sequence': 'GGTAATACTAAGTGATTGAC', 'PAM': 'CCG', '20-mers matching': 1, '12-mers matching': 1, '8-mers matching': 1}
# {'location': 864, 'type': 'Reverse', 'sequence': 'TTTATTAAGAACTAAATGGA', 'PAM': 'CCT', '20-mers matching': 1, '12-mers matching': 1, '8-mers matching': 1}
# {'location': 954, 'type': 'Reverse', 'sequence': 'ACTATAACAATCAAGAAAAA', 'PAM': 'CCT', '20-mers matching': 1, '12-mers matching': 1, '8-mers matching': 1}
# {'location': 1115, 'type': 'Reverse', 'sequence': 'GCCAAACAAATAAGCAACTC', 'PAM': 'CCT', '20-mers matching': 1, '12-mers matching': 1, '8-mers matching': 1}
# {'location': 1119, 'type': 'Reverse', 'sequence': 'AACAAATAAGCAACTCCAAT', 'PAM': 'CCA', '20-mers matching': 1, '12-mers matching': 1, '8-mers matching': 1}
# {'location': 1137, 'type': 'Reverse', 'sequence': 'ATGACCACGTTAATGGCTCC', 'PAM': 'CCA', '20-mers matching': 1, '12-mers matching': 1, '8-mers matching': 1}
# {'location': 1144, 'type': 'Reverse', 'sequence': 'CGTTAATGGCTCCTTTTCCA', 'PAM': 'CCA', '20-mers matching': 1, '12-mers matching': 1, '8-mers matching': 1}
# {'location': 1158, 'type': 'Reverse', 'sequence': 'TTTCCAATCCTCTTGATATC', 'PAM': 'CCT', '20-mers matching': 1, '12-mers matching': 1, '8-mers matching': 1}
# {'location': 1164, 'type': 'Reverse', 'sequence': 'ATCCTCTTGATATCGAAAAA', 'PAM': 'CCA', '20-mers matching': 1, '12-mers matching': 1, '8-mers matching': 1}
# {'location': 1169, 'type': 'Reverse', 'sequence': 'CTTGATATCGAAAAACTAGC', 'PAM': 'CCT', '20-mers matching': 1, '12-mers matching': 1, '8-mers matching': 1}
# {'location': 1238, 'type': 'Reverse', 'sequence': 'ACACTAAAGAATCTTCAAGT', 'PAM': 'CCT', '20-mers matching': 1, '12-mers matching': 1, '8-mers matching': 1}
# {'location': 1268, 'type': 'Reverse', 'sequence': 'AAATTAAAAATTTACCCTTC', 'PAM': 'CCC', '20-mers matching': 1, '12-mers matching': 1, '8-mers matching': 1}
# {'location': 1269, 'type': 'Reverse', 'sequence': 'AATTAAAAATTTACCCTTCT', 'PAM': 'CCA', '20-mers matching': 1, '12-mers matching': 1, '8-mers matching': 1}
# {'location': 1285, 'type': 'Reverse', 'sequence': 'TTCTCCAGAAACAATCAGAT', 'PAM': 'CCC', '20-mers matching': 1, '12-mers matching': 1, '8-mers matching': 1}
# {'location': 1286, 'type': 'Reverse', 'sequence': 'TCTCCAGAAACAATCAGATT', 'PAM': 'CCT', '20-mers matching': 1, '12-mers matching': 1, '8-mers matching': 1}
# {'location': 1292, 'type': 'Reverse', 'sequence': 'GAAACAATCAGATTGATACA', 'PAM': 'CCA', '20-mers matching': 1, '12-mers matching': 1, '8-mers matching': 1}
# {'location': 1365, 'type': 'Reverse', 'sequence': 'AAAGTGTTCCTGTGGAACAA', 'PAM': 'CCC', '20-mers matching': 1, '12-mers matching': 1, '8-mers matching': 1}
# {'location': 1366, 'type': 'Reverse', 'sequence': 'AAGTGTTCCTGTGGAACAAG', 'PAM': 'CCA', '20-mers matching': 1, '12-mers matching': 1, '8-mers matching': 1}
# {'location': 1376, 'type': 'Reverse', 'sequence': 'GTGGAACAAGCCAGTGAGAC', 'PAM': 'CCT', '20-mers matching': 1, '12-mers matching': 1, '8-mers matching': 1}
# {'location': 1389, 'type': 'Reverse', 'sequence': 'GTGAGACGTCCCTATTGAAT', 'PAM': 'CCA', '20-mers matching': 1, '12-mers matching': 1, '8-mers matching': 1}
# {'location': 1401, 'type': 'Reverse', 'sequence': 'TATTGAATGTTGGAAGAGAT', 'PAM': 'CCC', '20-mers matching': 1, '12-mers matching': 1, '8-mers matching': 1}
# {'location': 1402, 'type': 'Reverse', 'sequence': 'ATTGAATGTTGGAAGAGATT', 'PAM': 'CCT', '20-mers matching': 1, '12-mers matching': 1, '8-mers matching': 1}
# {'location': 1433, 'type': 'Reverse', 'sequence': 'TTCGTCTTGAAGTCGAGGAC', 'PAM': 'CCA', '20-mers matching': 1, '12-mers matching': 1, '8-mers matching': 1}
# {'location': 1508, 'type': 'Reverse', 'sequence': 'GAAGCTTTGGAAGTACTGAA', 'PAM': 'CCG', '20-mers matching': 1, '12-mers matching': 1, '8-mers matching': 1}
# {'location': 1538, 'type': 'Reverse', 'sequence': 'TTGTACGCCGAAAAATGGGC', 'PAM': 'CCT', '20-mers matching': 1, '12-mers matching': 1, '8-mers matching': 1}
# {'location': 1548, 'type': 'Reverse', 'sequence': 'AAAAATGGGCACCATTTACT', 'PAM': 'CCG', '20-mers matching': 1, '12-mers matching': 1, '8-mers matching': 1}
# {'location': 1562, 'type': 'Reverse', 'sequence': 'TTTACTAAAGAATTAGCAGT', 'PAM': 'CCA', '20-mers matching': 1, '12-mers matching': 1, '8-mers matching': 1}
# {'location': 1624, 'type': 'Reverse', 'sequence': 'AATTGTAGAGACTATCCACA', 'PAM': 'CCC', '20-mers matching': 1, '12-mers matching': 1, '8-mers matching': 1}
# {'location': 1625, 'type': 'Reverse', 'sequence': 'ATTGTAGAGACTATCCACAA', 'PAM': 'CCA', '20-mers matching': 1, '12-mers matching': 1, '8-mers matching': 1}
# {'location': 1642, 'type': 'Reverse', 'sequence': 'CAAGGACAATATTTGTGACT', 'PAM': 'CCA', '20-mers matching': 1, '12-mers matching': 1, '8-mers matching': 1}
# {'location': 1676, 'type': 'Reverse', 'sequence': 'GCTAGAGTTCCGGACTCCGT', 'PAM': 'CCT', '20-mers matching': 1, '12-mers matching': 1, '8-mers matching': 1}
# {'location': 1688, 'type': 'Reverse', 'sequence': 'GACTCCGTTCAACTTAAGGC', 'PAM': 'CCG', '20-mers matching': 1, '12-mers matching': 1, '8-mers matching': 1}
# {'location': 1695, 'type': 'Reverse', 'sequence': 'TTCAACTTAAGGCGAAGTTG', 'PAM': 'CCG', '20-mers matching': 1, '12-mers matching': 1, '8-mers matching': 1}
# {'location': 1745, 'type': 'Reverse', 'sequence': 'GGTTGTGGTATATTTGGTGT', 'PAM': 'CCC', '20-mers matching': 1, '12-mers matching': 1, '8-mers matching': 1}
# {'location': 1746, 'type': 'Reverse', 'sequence': 'GTTGTGGTATATTTGGTGTG', 'PAM': 'CCG', '20-mers matching': 1, '12-mers matching': 1, '8-mers matching': 1}
# {'location': 1815, 'type': 'Reverse', 'sequence': 'CAAGGCCTCACAACTCTGGA', 'PAM': 'CCC', '20-mers matching': 1, '12-mers matching': 1, '8-mers matching': 1}
# {'location': 1816, 'type': 'Reverse', 'sequence': 'AAGGCCTCACAACTCTGGAC', 'PAM': 'CCC', '20-mers matching': 1, '12-mers matching': 1, '8-mers matching': 1}
# {'location': 1817, 'type': 'Reverse', 'sequence': 'AGGCCTCACAACTCTGGACA', 'PAM': 'CCA', '20-mers matching': 1, '12-mers matching': 1, '8-mers matching': 1}
# {'location': 1823, 'type': 'Reverse', 'sequence': 'CACAACTCTGGACATTATAC', 'PAM': 'CCT', '20-mers matching': 1, '12-mers matching': 1, '8-mers matching': 1}
# {'location': 1845, 'type': 'Reverse', 'sequence': 'TTGATGCTTGCGTCACTTCT', 'PAM': 'CCA', '20-mers matching': 1, '12-mers matching': 1, '8-mers matching': 1}
# {'location': 1904, 'type': 'Reverse', 'sequence': 'ATGCCAAAGAATTTCACATC', 'PAM': 'CCA', '20-mers matching': 1, '12-mers matching': 1, '8-mers matching': 1}
# {'location': 1910, 'type': 'Reverse', 'sequence': 'AAGAATTTCACATCTTTCTC', 'PAM': 'CCA', '20-mers matching': 1, '12-mers matching': 1, '8-mers matching': 1}
# {'location': 1932, 'type': 'Reverse', 'sequence': 'CCATTACAACGAACGCCATT', 'PAM': 'CCA', '20-mers matching': 1, '12-mers matching': 1, '8-mers matching': 1}
# {'location': 1935, 'type': 'Reverse', 'sequence': 'TTACAACGAACGCCATTATG', 'PAM': 'CCA', '20-mers matching': 1, '12-mers matching': 1, '8-mers matching': 1}
# {'location': 1950, 'type': 'Reverse', 'sequence': 'TTATGCTAAATGTTCTTGGA', 'PAM': 'CCA', '20-mers matching': 1, '12-mers matching': 1, '8-mers matching': 1}
# {'location': 2027, 'type': 'Reverse', 'sequence': 'GGTTCCTCAGTGTACTTATA', 'PAM': 'CCA', '20-mers matching': 1, '12-mers matching': 1, '8-mers matching': 1}
# {'location': 2034, 'type': 'Reverse', 'sequence': 'CAGTGTACTTATATGGAAAA', 'PAM': 'CCT', '20-mers matching': 1, '12-mers matching': 1, '8-mers matching': 1}
# {'location': 2066, 'type': 'Reverse', 'sequence': 'AACAGAAAAGTAGGTCACAT', 'PAM': 'CCT', '20-mers matching': 1, '12-mers matching': 1, '8-mers matching': 1}
# {'location': 2100, 'type': 'Reverse', 'sequence': 'CCAGTATGGCGGAATGTGAA', 'PAM': 'CCT', '20-mers matching': 1, '12-mers matching': 1, '8-mers matching': 1}
# {'location': 2103, 'type': 'Reverse', 'sequence': 'GTATGGCGGAATGTGAACAA', 'PAM': 'CCA', '20-mers matching': 1, '12-mers matching': 1, '8-mers matching': 1}
# {'location': 2159, 'type': 'Reverse', 'sequence': 'ATCAAAATCTCTGTCGCTCA', 'PAM': 'CCA', '20-mers matching': 1, '12-mers matching': 1, '8-mers matching': 1}
# {'location': 2210, 'type': 'Reverse', 'sequence': 'TTGGTTGGAATCATCATGGG', 'PAM': 'CCA', '20-mers matching': 1, '12-mers matching': 1, '8-mers matching': 1}
# {'location': 2249, 'type': 'Reverse', 'sequence': 'GTAATGTCTGCCGCATGTGC', 'PAM': 'CCG', '20-mers matching': 1, '12-mers matching': 1, '8-mers matching': 1}
# {'location': 2262, 'type': 'Reverse', 'sequence': 'CATGTGCGGTTTTAAAAGAT', 'PAM': 'CCG', '20-mers matching': 1, '12-mers matching': 1, '8-mers matching': 1}
# {'location': 2294, 'type': 'Reverse', 'sequence': 'TTTGAAGTGACAATAGTCTC', 'PAM': 'CCA', '20-mers matching': 1, '12-mers matching': 1, '8-mers matching': 1}
# {'location': 2330, 'type': 'Reverse', 'sequence': 'CATAGGATGTCAGCATATGC', 'PAM': 'CCA', '20-mers matching': 1, '12-mers matching': 1, '8-mers matching': 1}
# {'location': 2358, 'type': 'Reverse', 'sequence': 'CAAGCAAGCGTGGAATTAAA', 'PAM': 'CCG', '20-mers matching': 1, '12-mers matching': 1, '8-mers matching': 1}
# {'location': 2417, 'type': 'Reverse', 'sequence': 'GGTATGGTGGCTGCAATGAC', 'PAM': 'CCA', '20-mers matching': 1, '12-mers matching': 1, '8-mers matching': 1}
# {'location': 2441, 'type': 'Reverse', 'sequence': 'CTTCCTGTCATCGGTGTGCC', 'PAM': 'CCA', '20-mers matching': 1, '12-mers matching': 1, '8-mers matching': 1}
# {'location': 2447, 'type': 'Reverse', 'sequence': 'GTCATCGGTGTGCCCGTAAA', 'PAM': 'CCT', '20-mers matching': 1, '12-mers matching': 1, '8-mers matching': 1}
# {'location': 2462, 'type': 'Reverse', 'sequence': 'GTAAAAGGTTCTTGTCTAGA', 'PAM': 'CCC', '20-mers matching': 1, '12-mers matching': 1, '8-mers matching': 1}
# {'location': 2463, 'type': 'Reverse', 'sequence': 'TAAAAGGTTCTTGTCTAGAT', 'PAM': 'CCG', '20-mers matching': 1, '12-mers matching': 1, '8-mers matching': 1}
# {'location': 2519, 'type': 'Reverse', 'sequence': 'AGAGGTGTTCCAGTAGCTAC', 'PAM': 'CCT', '20-mers matching': 1, '12-mers matching': 1, '8-mers matching': 1}
# {'location': 2531, 'type': 'Reverse', 'sequence': 'GTAGCTACCGTCGCTATTAA', 'PAM': 'CCA', '20-mers matching': 1, '12-mers matching': 1, '8-mers matching': 1}
# {'location': 2541, 'type': 'Reverse', 'sequence': 'TCGCTATTAATAATAGTACG', 'PAM': 'CCG', '20-mers matching': 1, '12-mers matching': 1, '8-mers matching': 1}
# {'location': 2771, 'type': 'Reverse', 'sequence': 'ATTTTTTAGGCTTTGTTATG', 'PAM': 'CCT', '20-mers matching': 1, '12-mers matching': 1, '8-mers matching': 1}
# {'location': 2843, 'type': 'Reverse', 'sequence': 'TTTTTAAGAATTTCATACAT', 'PAM': 'CCT', '20-mers matching': 1, '12-mers matching': 1, '8-mers matching': 1}
# {'location': 2895, 'type': 'Reverse', 'sequence': 'GTAACAAGAAGCAAGGAATA', 'PAM': 'CCA', '20-mers matching': 1, '12-mers matching': 1, '8-mers matching': 1}
# {'location': 2922, 'type': 'Reverse', 'sequence': 'GCTTAAGTCTGCGATTAAAA', 'PAM': 'CCT', '20-mers matching': 1, '12-mers matching': 1, '8-mers matching': 1}
# {'location': 2990, 'type': 'Reverse', 'sequence': 'AGGATAGCGCTACGTCAGGA', 'PAM': 'CCG', '20-mers matching': 1, '12-mers matching': 1, '8-mers matching': 1}
# {'location': 3026, 'type': 'Reverse', 'sequence': 'AAATATAAATGCGACAATAT', 'PAM': 'CCC', '20-mers matching': 1, '12-mers matching': 1, '8-mers matching': 1}
# {'location': 3027, 'type': 'Reverse', 'sequence': 'AATATAAATGCGACAATATA', 'PAM': 'CCA', '20-mers matching': 1, '12-mers matching': 1, '8-mers matching': 1}
# {'location': 3076, 'type': 'Reverse', 'sequence': 'TTTCTCCACTGAAATCACGA', 'PAM': 'CCT', '20-mers matching': 1, '12-mers matching': 1, '8-mers matching': 1}
# {'location': 3084, 'type': 'Reverse', 'sequence': 'CTGAAATCACGAATCAAACC', 'PAM': 'CCA', '20-mers matching': 1, '12-mers matching': 1, '8-mers matching': 1}
# {'location': 3105, 'type': 'Reverse', 'sequence': 'GGAGCAAAAACTAAAGCCAA', 'PAM': 'CCT', '20-mers matching': 1, '12-mers matching': 1, '8-mers matching': 1}
# {'location': 3124, 'type': 'Reverse', 'sequence': 'AATTATAAAGCGTCATTCGA', 'PAM': 'CCA', '20-mers matching': 1, '12-mers matching': 1, '8-mers matching': 1}
# {'location': 3149, 'type': 'Reverse', 'sequence': 'GTGACTGTACCGTGTAACCT', 'PAM': 'CCA', '20-mers matching': 1, '12-mers matching': 1, '8-mers matching': 1}
# {'location': 3161, 'type': 'Reverse', 'sequence': 'TGTAACCTTTTCTATATGTT', 'PAM': 'CCG', '20-mers matching': 1, '12-mers matching': 1, '8-mers matching': 1}
# {'location': 3169, 'type': 'Reverse', 'sequence': 'TTTCTATATGTTCACTCAGT', 'PAM': 'CCT', '20-mers matching': 1, '12-mers matching': 1, '8-mers matching': 1}
# {'location': 3202, 'type': 'Reverse', 'sequence': 'TATAATGTTCCCTTGGAAGG', 'PAM': 'CCC', '20-mers matching': 1, '12-mers matching': 1, '8-mers matching': 1}
# {'location': 3203, 'type': 'Reverse', 'sequence': 'ATAATGTTCCCTTGGAAGGT', 'PAM': 'CCT', '20-mers matching': 1, '12-mers matching': 1, '8-mers matching': 1}
# {'location': 3214, 'type': 'Reverse', 'sequence': 'TTGGAAGGTCTTCCAATATG', 'PAM': 'CCC', '20-mers matching': 1, '12-mers matching': 1, '8-mers matching': 1}
# {'location': 3215, 'type': 'Reverse', 'sequence': 'TGGAAGGTCTTCCAATATGT', 'PAM': 'CCT', '20-mers matching': 1, '12-mers matching': 1, '8-mers matching': 1}
# {'location': 3229, 'type': 'Reverse', 'sequence': 'ATATGTTTTTTAAAGCGCTC', 'PAM': 'CCA', '20-mers matching': 1, '12-mers matching': 1, '8-mers matching': 1}
# {'location': 3271, 'type': 'Reverse', 'sequence': 'AATTCTTTGCTTCTAAGGAC', 'PAM': 'CCG', '20-mers matching': 1, '12-mers matching': 1, '8-mers matching': 1}
# {'location': 3300, 'type': 'Reverse', 'sequence': 'CCAACAAATGGCAAGTTTTC', 'PAM': 'CCT', '20-mers matching': 1, '12-mers matching': 1, '8-mers matching': 1}
# {'location': 3303, 'type': 'Reverse', 'sequence': 'ACAAATGGCAAGTTTTCCAT', 'PAM': 'CCA', '20-mers matching': 1, '12-mers matching': 1, '8-mers matching': 1}
# {'location': 3322, 'type': 'Reverse', 'sequence': 'TCATTTTTTTAGATTTAACT', 'PAM': 'CCA', '20-mers matching': 1, '12-mers matching': 1, '8-mers matching': 1}
# {'location': 3347, 'type': 'Reverse', 'sequence': 'CATCAACGGCTCGTATATTT', 'PAM': 'CCT', '20-mers matching': 1, '12-mers matching': 1, '8-mers matching': 1}
# {'location': 3420, 'type': 'Reverse', 'sequence': 'GTAACAACGTTGAGATCTTG', 'PAM': 'CCA', '20-mers matching': 1, '12-mers matching': 1, '8-mers matching': 1}
# {'location': 3445, 'type': 'Reverse', 'sequence': 'TTAAAATATTTGGCGTTTCG', 'PAM': 'CCG', '20-mers matching': 1, '12-mers matching': 1, '8-mers matching': 1}
# {'location': 3485, 'type': 'Reverse', 'sequence': 'TGCAGAAAATTGCTTTTCTA', 'PAM': 'CCA', '20-mers matching': 1, '12-mers matching': 1, '8-mers matching': 1}
# {'location': 3531, 'type': 'Reverse', 'sequence': 'GATTTTCTATAAATGCCCTC', 'PAM': 'CCT', '20-mers matching': 1, '12-mers matching': 1, '8-mers matching': 1}
# {'location': 3549, 'type': 'Reverse', 'sequence': 'TCCGATCTCATATTTTCTTC', 'PAM': 'CCC', '20-mers matching': 1, '12-mers matching': 1, '8-mers matching': 1}
# {'location': 3550, 'type': 'Reverse', 'sequence': 'CCGATCTCATATTTTCTTCG', 'PAM': 'CCT', '20-mers matching': 1, '12-mers matching': 1, '8-mers matching': 1}
# {'location': 3553, 'type': 'Reverse', 'sequence': 'ATCTCATATTTTCTTCGTCT', 'PAM': 'CCG', '20-mers matching': 1, '12-mers matching': 1, '8-mers matching': 1}
# {'location': 3638, 'type': 'Reverse', 'sequence': 'AGCAACGAGACTTGAACCAT', 'PAM': 'CCT', '20-mers matching': 1, '12-mers matching': 1, '8-mers matching': 1}
# {'location': 3657, 'type': 'Reverse', 'sequence': 'TACAAATTGCTTCCATCCAA', 'PAM': 'CCA', '20-mers matching': 1, '12-mers matching': 1, '8-mers matching': 1}
# {'location': 3672, 'type': 'Reverse', 'sequence': 'TCCAAATATTCTTCTCCATC', 'PAM': 'CCA', '20-mers matching': 1, '12-mers matching': 1, '8-mers matching': 1}
# {'location': 3676, 'type': 'Reverse', 'sequence': 'AATATTCTTCTCCATCTTTA', 'PAM': 'CCA', '20-mers matching': 1, '12-mers matching': 1, '8-mers matching': 1}
# {'location': 3690, 'type': 'Reverse', 'sequence': 'TCTTTACTTTGTCCCATATT', 'PAM': 'CCA', '20-mers matching': 1, '12-mers matching': 1, '8-mers matching': 1}
